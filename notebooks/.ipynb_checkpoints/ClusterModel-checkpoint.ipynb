# %% [markdown]
# # IoT Anomaly Detection - Cluster Models
#
# The purpose of this notebook is to create model per group of devices of the same type.

# %%
# imports
import sys
sys.path.append('../src')
from main import main
from ConfigConsts import *
from collections import OrderedDict

# %%
# Consts
CLUSTER_DIR = "@../args/cluster/"
CLUSTER_ARGS_FILE_PATH = CLUSTER_DIR + "{}_Cluster.txt"
CLUSTER_DELIMETER = "_"
DOORBELLS = DANMINI_DOORBELL + CLUSTER_DELIMETER + ENNIO_DOORBELL
PROV_SECURITY_CAM = PROV_737_SECURITY_CAM + CLUSTER_DELIMETER + PROV_838_SECURITY_CAM
SIMPLE_HOME_SECURITY_CAM = SIMPLE_HOME_1002_SECURITY_CAM + CLUSTER_DELIMETER + SIMPLE_HOME_1003_SECURITY_CAM
SECURITY_CAMS = SIMPLE_HOME_SECURITY_CAM + CLUSTER_DELIMETER + PROV_SECURITY_CAM
CLUSTER_ALL = "All"

CLUSTER_ARGS_FILES = [
    (DOORBELLS,                      [CLUSTER_ARGS_FILE_PATH.format(DOORBELLS)]),
    (PROV_SECURITY_CAM,              [CLUSTER_ARGS_FILE_PATH.format(PROV_SECURITY_CAM)]),
    (SIMPLE_HOME_SECURITY_CAM,       [CLUSTER_ARGS_FILE_PATH.format(SIMPLE_HOME_SECURITY_CAM)]),
    (SECURITY_CAMS,                  [CLUSTER_ARGS_FILE_PATH.format(SECURITY_CAMS)]),
    (CLUSTER_ALL,                    [CLUSTER_ARGS_FILE_PATH.format(CLUSTER_ALL)]),
]

# %%
dfs_results = OrderedDict()
for iot, args in CLUSTER_ARGS_FILES:
    dfs_results[iot] = main(args)
# Out:
# Configuration:
# ================
# name=Danmini_Doorbell_Ennio_Doorbell_Cluster
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.012
# epochs=800
# batch_size=32
# iots=['Danmini_Doorbell', 'Ennio_Doorbell']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=Danmini_Doorbell_Ennio_Doorbell_Cluster
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 23]             897
#            Sigmoid-8                [-1, 1, 23]               0
#             Linear-9                [-1, 1, 38]             912
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,164
# Trainable params: 36,164
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.131233, val avg loss 0.090146
# Epoch 50, train avg loss 0.020624, val avg loss 0.016387
# Epoch 100, train avg loss 0.020504, val avg loss 0.016256
# Epoch 150, train avg loss 0.020471, val avg loss 0.016226
# Epoch 200, train avg loss 0.020456, val avg loss 0.016215
# Epoch 250, train avg loss 0.020447, val avg loss 0.016210
# Epoch 300, train avg loss 0.020441, val avg loss 0.016209
# Epoch 350, train avg loss 0.020437, val avg loss 0.016209
# Epoch 400, train avg loss 0.020435, val avg loss 0.016209
# Epoch 450, train avg loss 0.020432, val avg loss 0.016210
# Epoch 500, train avg loss 0.020430, val avg loss 0.016210
# Epoch 550, train avg loss 0.020429, val avg loss 0.016211
# Epoch 600, train avg loss 0.020428, val avg loss 0.016212
# Epoch 650, train avg loss 0.020427, val avg loss 0.016213
# Epoch 700, train avg loss 0.020426, val avg loss 0.016214
# Epoch 750, train avg loss 0.020425, val avg loss 0.016215
# Saving trained model to file ../models/Danmini_Doorbell_Ennio_Doorbell_Cluster
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x000002196641FEF0>
# tr*:   0.025612883269786835
# ws*:   170
#
# Configuration:
# ================
# name=Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.02
# epochs=350
# batch_size=32
# iots=['Provision_737_Security_Camera', 'Provision_838_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 23]             897
#            Sigmoid-8                [-1, 1, 23]               0
#             Linear-9                [-1, 1, 38]             912
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,164
# Trainable params: 36,164
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.077500, val avg loss 0.041933
# Epoch 50, train avg loss 0.024557, val avg loss 0.027764
# Epoch 100, train avg loss 0.024544, val avg loss 0.027756
# Epoch 150, train avg loss 0.024540, val avg loss 0.027754
# Epoch 200, train avg loss 0.024538, val avg loss 0.027754
# Epoch 250, train avg loss 0.024537, val avg loss 0.027753
# Epoch 300, train avg loss 0.024536, val avg loss 0.027753
# Saving trained model to file ../models/Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x00000219138E9278>
# tr*:   0.0612340085208416
# ws*:   230
#
# Configuration:
# ================
# name=Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Cluster
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.01
# epochs=300
# batch_size=32
# iots=['Simple_Home_1002_Security_Camera', 'Simple_Home_1003_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Cluster
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 23]             897
#            Sigmoid-8                [-1, 1, 23]               0
#             Linear-9                [-1, 1, 38]             912
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,164
# Trainable params: 36,164
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.133916, val avg loss 0.107948
# Epoch 50, train avg loss 0.023396, val avg loss 0.025530
# Epoch 100, train avg loss 0.023127, val avg loss 0.025376
# Epoch 150, train avg loss 0.023063, val avg loss 0.025353
# Epoch 200, train avg loss 0.023037, val avg loss 0.025348
# Epoch 250, train avg loss 0.023023, val avg loss 0.025348
# Saving trained model to file ../models/Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Cluster
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x00000219138E99B0>
# tr*:   0.05363556370139122
# ws*:   1298
#
# Configuration:
# ================
# name=Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster.txt
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.01
# epochs=325
# batch_size=32
# iots=['Simple_Home_1002_Security_Camera', 'Simple_Home_1003_Security_Camera', 'Provision_737_Security_Camera', 'Provision_838_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 23]             897
#            Sigmoid-8                [-1, 1, 23]               0
#             Linear-9                [-1, 1, 38]             912
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,164
# Trainable params: 36,164
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.097909, val avg loss 0.056974
# Epoch 50, train avg loss 0.029148, val avg loss 0.031724
# Epoch 100, train avg loss 0.029128, val avg loss 0.031709
# Epoch 150, train avg loss 0.029121, val avg loss 0.031706
# Epoch 200, train avg loss 0.029118, val avg loss 0.031705
# Epoch 250, train avg loss 0.029116, val avg loss 0.031705
# Epoch 300, train avg loss 0.029114, val avg loss 0.031705
# Saving trained model to file ../models/Simple_Home_1002_Security_Camera_Simple_Home_1003_Security_Camera_Provision_737_Security_Camera_Provision_838_Security_Camera_Cluster
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x0000021913ABEC50>
# tr*:   0.06566183269023895
# ws*:   1464
#
# Configuration:
# ================
# name=All_Cluster
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.012
# epochs=800
# batch_size=32
# iots=['Danmini_Doorbell', 'Ecobee_Thermostat', 'Ennio_Doorbell', 'Philips_Baby_Monitor', 'Provision_737_Security_Camera', 'Provision_838_Security_Camera', 'Samsung_Webcam', 'Simple_Home_1002_Security_Camera', 'Simple_Home_1003_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=All_Cluster
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 23]             897
#            Sigmoid-8                [-1, 1, 23]               0
#             Linear-9                [-1, 1, 38]             912
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,164
# Trainable params: 36,164
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.056454, val avg loss 0.029850
# Epoch 50, train avg loss 0.023626, val avg loss 0.024983
# Epoch 100, train avg loss 0.023612, val avg loss 0.025002
# Epoch 150, train avg loss 0.023605, val avg loss 0.025013
# Epoch 200, train avg loss 0.023601, val avg loss 0.025021
# Epoch 250, train avg loss 0.023599, val avg loss 0.025027
# Epoch 300, train avg loss 0.023596, val avg loss 0.025032
# Epoch 350, train avg loss 0.023595, val avg loss 0.025036
# Epoch 400, train avg loss 0.023593, val avg loss 0.025040
# Epoch 450, train avg loss 0.023591, val avg loss 0.025043
# Epoch 500, train avg loss 0.023590, val avg loss 0.025047
# Epoch 550, train avg loss 0.023589, val avg loss 0.025050
# Epoch 600, train avg loss 0.023587, val avg loss 0.025053
# Epoch 650, train avg loss 0.023586, val avg loss 0.025056
# Epoch 700, train avg loss 0.023585, val avg loss 0.025059
# Epoch 750, train avg loss 0.023584, val avg loss 0.025063
# Saving trained model to file ../models/All_Cluster
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x0000021913ABEDD8>
# tr*:   0.052990518510341644
# ws*:   3404

# %%
for iot, results in dfs_results.items():
    display(results)
# Out:
#                 Danmini_Doorbell  Ennio_Doorbell
# benign_test             0.000000        0.002031
# gafgyt_combo            0.998593        0.998416
# gafgyt_junk             0.997110        0.997181
# gafgyt_scan             0.997186        0.992931
# gafgyt_tcp              0.999088        0.999163
# gafgyt_udp              0.999197        0.999182
# mirai_ack               0.999178             NaN
# mirai_scan              0.999220             NaN
# mirai_syn               0.999315             NaN
# mirai_udp               0.999647             NaN
# mirai_udpplain          0.998975             NaN
#                 Provision_737_Security_Camera  Provision_838_Security_Camera
# benign_test                          0.000000                       0.001164
# gafgyt_combo                         0.998012                       0.997827
# gafgyt_junk                          0.995793                       0.995803
# gafgyt_scan                          0.995802                       0.995528
# gafgyt_tcp                           0.000000                       0.000000
# gafgyt_udp                           0.000000                       0.000000
# mirai_ack                            0.997919                       0.997827
# mirai_scan                           0.998760                       0.998702
# mirai_syn                            0.998053                       0.998060
# mirai_udp                            0.999245                       0.999256
# mirai_udpplain                       0.997901                       0.997825
#                 Simple_Home_1002_Security_Camera  \
# benign_test                             0.010291
# gafgyt_combo                            0.988044
# gafgyt_junk                             0.977046
# gafgyt_scan                             0.976640
# gafgyt_tcp                              0.992681
# gafgyt_udp                              0.993723
# mirai_ack                               0.994187
# mirai_scan                              0.985892
# mirai_syn                               0.994814
# mirai_udp                               0.995733
# mirai_udpplain                          0.991718
#
#                 Simple_Home_1003_Security_Camera
# benign_test                             0.000000
# gafgyt_combo                            0.988956
# gafgyt_junk                             0.976325
# gafgyt_scan                             0.977250
# gafgyt_tcp                              0.993383
# gafgyt_udp                              0.993678
# mirai_ack                               0.993954
# mirai_scan                              0.985163
# mirai_syn                               0.994644
# mirai_udp                               0.995875
# mirai_udpplain                          0.992326
#                 Provision_737_Security_Camera  Provision_838_Security_Camera  \
# benign_test                          0.000000                       0.000000
# gafgyt_combo                         0.987960                       0.987102
# gafgyt_junk                          0.975824                       0.974577
# gafgyt_scan                          0.974741                       0.973800
# gafgyt_tcp                           0.000000                       0.000000
# gafgyt_udp                           0.000000                       0.000000
# mirai_ack                            0.987730                       0.987189
# mirai_scan                           0.992385                       0.992348
# mirai_syn                            0.988669                       0.988084
# mirai_udp                            0.995245                       0.995328
# mirai_udpplain                       0.986997                       0.986334
#
#                 Simple_Home_1002_Security_Camera  \
# benign_test                             0.000379
# gafgyt_combo                            0.986441
# gafgyt_junk                             0.973862
# gafgyt_scan                             0.973010
# gafgyt_tcp                              0.000000
# gafgyt_udp                              0.000000
# mirai_ack                               0.993443
# mirai_scan                              0.983693
# mirai_syn                               0.994122
# mirai_udp                               0.995128
# mirai_udpplain                          0.990645
#
#                 Simple_Home_1003_Security_Camera
# benign_test                             0.000000
# gafgyt_combo                            0.987356
# gafgyt_junk                             0.973078
# gafgyt_scan                             0.973261
# gafgyt_tcp                              0.000000
# gafgyt_udp                              0.000000
# mirai_ack                               0.993180
# mirai_scan                              0.983010
# mirai_syn                               0.993917
# mirai_udp                               0.995302
# mirai_udpplain                          0.991331
#                 Danmini_Doorbell  Ecobee_Thermostat  Ennio_Doorbell  \
# benign_test             0.000000           0.000000        0.000000
# gafgyt_combo            0.971449           0.967837        0.967744
# gafgyt_junk             0.940932           0.943620        0.942679
# gafgyt_scan             0.942879           0.937986        0.856518
# gafgyt_tcp              0.981496           0.982057        0.983208
# gafgyt_udp              0.983877           0.983701        0.983566
# mirai_ack               0.983355           0.984985             NaN
# mirai_scan              0.984204           0.960618             NaN
# mirai_syn               0.986065           0.985309             NaN
# mirai_udp               0.992843           0.988771             NaN
# mirai_udpplain          0.979252           0.980531             NaN
#
#                 Philips_Baby_Monitor  Provision_737_Security_Camera  \
# benign_test                 0.000000                       0.000000
# gafgyt_combo                0.970491                       0.972190
# gafgyt_junk                 0.939433                       0.944495
# gafgyt_scan                 0.938799                       0.941803
# gafgyt_tcp                  0.981584                       0.983686
# gafgyt_udp                  0.983854                       0.983579
# mirai_ack                   0.981333                       0.971909
# mirai_scan                  0.983584                       0.982424
# mirai_syn                   0.985482                       0.974128
# mirai_udp                   0.992163                       0.989113
# mirai_udpplain              0.978950                       0.969990
#
#                 Provision_838_Security_Camera  Samsung_Webcam  \
# benign_test                          0.000000        0.000000
# gafgyt_combo                         0.970276        0.970802
# gafgyt_junk                          0.941276        0.939693
# gafgyt_scan                          0.939958        0.938443
# gafgyt_tcp                           0.980926        0.982563
# gafgyt_udp                           0.983680        0.984559
# mirai_ack                            0.970671             NaN
# mirai_scan                           0.982481             NaN
# mirai_syn                            0.972498             NaN
# mirai_udp                            0.989275             NaN
# mirai_udpplain                       0.968374             NaN
#
#                 Simple_Home_1002_Security_Camera  \
# benign_test                             0.000000
# gafgyt_combo                            0.968609
# gafgyt_junk                             0.939991
# gafgyt_scan                             0.938724
# gafgyt_tcp                              0.980803
# gafgyt_udp                              0.983533
# mirai_ack                               0.984742
# mirai_scan                              0.962965
# mirai_syn                               0.986422
# mirai_udp                               0.988800
# mirai_udpplain                          0.978260
#
#                 Simple_Home_1003_Security_Camera
# benign_test                             0.000000
# gafgyt_combo                            0.971076
# gafgyt_junk                             0.937767
# gafgyt_scan                             0.940326
# gafgyt_tcp                              0.982615
# gafgyt_udp                              0.983414
# mirai_ack                               0.984131
# mirai_scan                              0.961052
# mirai_syn                               0.986014
# mirai_udp                               0.989171
# mirai_udpplain                          0.979855
