# %% [markdown]
# # IoT Anomaly Detection - Baseline
#
# The purpose of this notebook is to reproduce the results in the paper.

# %%
# imports
import sys
sys.path.append('../src')
from main import main
from ConfigConsts import *
from collections import OrderedDict

# %%
# Consts
BASELINE_ARGS_FILE_PATH = "@../args/Baseline/{}_Baseline.txt"
BASELINE_ARGS_FILES = [
    (DANMINI_DOORBELL,              [BASELINE_ARGS_FILE_PATH.format(DANMINI_DOORBELL)]),
    (ENNIO_DOORBELL,                [BASELINE_ARGS_FILE_PATH.format(ENNIO_DOORBELL)]),
    (ECOBEE_THERMOSTAT,             [BASELINE_ARGS_FILE_PATH.format(ECOBEE_THERMOSTAT)]),
    (PHILIPS_BABY_MONITOR,          [BASELINE_ARGS_FILE_PATH.format(PHILIPS_BABY_MONITOR)]),
    (PROV_737_SECURITY_CAM,         [BASELINE_ARGS_FILE_PATH.format(PROV_737_SECURITY_CAM)]),
    (PROV_838_SECURITY_CAM,         [BASELINE_ARGS_FILE_PATH.format(PROV_838_SECURITY_CAM)]),
    (SIMPLE_HOME_1002_SECURITY_CAM, [BASELINE_ARGS_FILE_PATH.format(SIMPLE_HOME_1002_SECURITY_CAM)]),
    (SIMPLE_HOME_1003_SECURITY_CAM, [BASELINE_ARGS_FILE_PATH.format(SIMPLE_HOME_1003_SECURITY_CAM)]),
    (SAMSUNG_WEB_CAM,               [BASELINE_ARGS_FILE_PATH.format(SAMSUNG_WEB_CAM)]),
]

# %%
dfs_results = OrderedDict()
for iot, args in BASELINE_ARGS_FILES:
    dfs_results[iot] = main(args)
# Out:
# Configuration:
# ================
# name=Danmini_Doorbell_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.012
# epochs=800
# batch_size=32
# iots=['Danmini_Doorbell']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.139290, val avg loss 0.108548
# Epoch 50, train avg loss 0.004932, val avg loss 0.005003
# Epoch 100, train avg loss 0.004604, val avg loss 0.004684
# Epoch 150, train avg loss 0.004511, val avg loss 0.004593
# Epoch 200, train avg loss 0.004469, val avg loss 0.004552
# Epoch 250, train avg loss 0.004446, val avg loss 0.004529
# Epoch 300, train avg loss 0.004431, val avg loss 0.004515
# Epoch 350, train avg loss 0.004421, val avg loss 0.004505
# Epoch 400, train avg loss 0.004413, val avg loss 0.004498
# Epoch 450, train avg loss 0.004408, val avg loss 0.004492
# Epoch 500, train avg loss 0.004404, val avg loss 0.004488
# Epoch 550, train avg loss 0.004400, val avg loss 0.004485
# Epoch 600, train avg loss 0.004397, val avg loss 0.004483
# Epoch 650, train avg loss 0.004395, val avg loss 0.004480
# Epoch 700, train avg loss 0.004393, val avg loss 0.004478
# Epoch 750, train avg loss 0.004392, val avg loss 0.004477
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x00000293C6358F60>
# tr*:   0.013408531434834003
# ws*:   94
#
# Configuration:
# ================
# name=Ennio_Doorbell_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.003
# epochs=350
# batch_size=32
# iots=['Ennio_Doorbell']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.182323, val avg loss 0.182824
# Epoch 50, train avg loss 0.021459, val avg loss 0.015283
# Epoch 100, train avg loss 0.016467, val avg loss 0.008800
# Epoch 150, train avg loss 0.015442, val avg loss 0.007365
# Epoch 200, train avg loss 0.015062, val avg loss 0.006815
# Epoch 250, train avg loss 0.014876, val avg loss 0.006541
# Epoch 300, train avg loss 0.014770, val avg loss 0.006384
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x00000293C5FA07B8>
# tr*:   0.016835160553455353
# ws*:   174
#
# Configuration:
# ================
# name=Ecobee_Thermostat_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.028
# epochs=250
# batch_size=32
# iots=['Ecobee_Thermostat']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.128449, val avg loss 0.112710
# Epoch 50, train avg loss 0.016754, val avg loss 0.016158
# Epoch 100, train avg loss 0.016390, val avg loss 0.015784
# Epoch 150, train avg loss 0.016313, val avg loss 0.015702
# Epoch 200, train avg loss 0.016283, val avg loss 0.015668
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x000002938EBFF518>
# tr*:   0.026318663731217384
# ws*:   18
#
# Configuration:
# ================
# name=Philips_Baby_Monitor_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.016
# epochs=100
# batch_size=32
# iots=['Philips_Baby_Monitor']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.082386, val avg loss 0.029652
# Epoch 50, train avg loss 0.006061, val avg loss 0.002573
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x000002938E590F98>
# tr*:   0.02019970864057541
# ws*:   286
#
# Configuration:
# ================
# name=Provision_737_Security_Camera_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.026
# epochs=300
# batch_size=32
# iots=['Provision_737_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.117608, val avg loss 0.072389
# Epoch 50, train avg loss 0.024765, val avg loss 0.025781
# Epoch 100, train avg loss 0.024733, val avg loss 0.025752
# Epoch 150, train avg loss 0.024725, val avg loss 0.025745
# Epoch 200, train avg loss 0.024721, val avg loss 0.025742
# Epoch 250, train avg loss 0.024719, val avg loss 0.025741
# model: <IoTAnomalyDetectorAutoEncoderNet.IoTAnomalyDetectorAutoEncoderNet object at 0x000002938E5EDBA8>
# tr*:   0.06476278603076935
# ws*:   164
#
# Configuration:
# ================
# name=Provision_838_Security_Camera_Baseline
# model=AutoEncoder
# loss=MSE
# optimizer=SGD
# learning_rate=0.008
# epochs=450
# batch_size=32
# iots=['Provision_838_Security_Camera']
# train_test_split=0.66
# train_val_split=0.8
# model_filename=None
# train=True
# test=True
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 86]           9,976
#            Sigmoid-2                [-1, 1, 86]               0
#             Linear-3                [-1, 1, 57]           4,959
#            Sigmoid-4                [-1, 1, 57]               0
#             Linear-5                [-1, 1, 38]           2,204
#            Sigmoid-6                [-1, 1, 38]               0
#             Linear-7                [-1, 1, 28]           1,092
#            Sigmoid-8                [-1, 1, 28]               0
#             Linear-9                [-1, 1, 38]           1,102
#           Sigmoid-10                [-1, 1, 38]               0
#            Linear-11                [-1, 1, 57]           2,223
#           Sigmoid-12                [-1, 1, 57]               0
#            Linear-13                [-1, 1, 86]           4,988
#           Sigmoid-14                [-1, 1, 86]               0
#            Linear-15               [-1, 1, 115]          10,005
#           Sigmoid-16               [-1, 1, 115]               0
# ================================================================
# Total params: 36,549
# Trainable params: 36,549
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.14
# Estimated Total Size (MB): 0.15
# ----------------------------------------------------------------
# Epoch 0, train avg loss 0.139760, val avg loss 0.105200
# Epoch 50, train avg loss 0.023289, val avg loss 0.027626
# Epoch 100, train avg loss 0.023192, val avg loss 0.027559
# Epoch 150, train avg loss 0.023169, val avg loss 0.027539
# Epoch 200, train avg loss 0.023159, val avg loss 0.027530
# Epoch 250, train avg loss 0.023153, val avg loss 0.027525
# Epoch 300, train avg loss 0.023150, val avg loss 0.027522
